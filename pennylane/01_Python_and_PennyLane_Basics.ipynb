# %% [markdown]
# # Notebook 01: PennyLane Setup and Core Concepts
#
# PennyLane is a cross-platform Python library developed by Xanadu for differentiable quantum programming and Quantum Machine Learning (QML).
#
# ---
#
# ## Learning Objectives
# 1. Verify PennyLane installation and version.
# 2. Initialize statevector simulation devices (`default.qubit`).
# 3. Inspect device properties and allocated wires.

# %% [markdown]
# ---
# ## Real-World Applications & Modern Use Cases
#
# PennyLane's hardware-agnostic, differentiable framework is used across enterprise quantum programs for:
# - **Quantum-Classical Hybrid Machine Learning:** Bridging standard Python deep learning toolkits with quantum backends for variational algorithm prototyping.
# - **Multi-Vendor QPU Deployment:** Writing hardware-agnostic algorithms that run unchanged across IBM Quantum, Rigetti, IonQ, and high-performance GPU simulators (Lightning).

# %%
import pennylane as qml
print("PennyLane Framework Version:", qml.__version__)
# Out:
# PennyLane Framework Version: 0.44.1
# C:\Users\erics\Downloads\Intro-to-Quantum-Computing-main\.venv\Lib\site-packages\pennylane\__init__.py:212: PennyLaneDeprecationWarning: PennyLane v0.44 has dropped maintainence support for NumPy < 2.0.0. You have version 1.26.4 installed. Future versions of PennyLane will not work with NumPy<2.0. Please consider upgrading NumPy using `python -m pip install numpy --upgrade`.
#   warnings.warn(

# %% [markdown]
# ---
# ## Section 1: Initializing Quantum Devices

# %%
# Initialize a 2-wire statevector simulator
dev = qml.device("default.qubit", wires=2)

print("Device Name:", dev.name)
print("Allocated Wires:", dev.wires)
print("Device Object:", dev)
# Out:
# Device Name: default.qubit
# Allocated Wires: Wires([0, 1])
# Device Object: <default.qubit device (wires=2) at 0x237d2ed3410>
